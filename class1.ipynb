# %% [markdown]
# # Sommaire

# %% [markdown]
# PYTHON 3

# %% [markdown]
# >[Sommaire](#scrollTo=WYyCyOO_r6lw)
#
# >[Imports classiques](#scrollTo=I4oNLLIcsJcg)
#
# >[Mise en place matérielle de l'environnement](#scrollTo=mkb9LHR1r_O0)
#
# >>[Copie des fichiers du drive vers la machine distante](#scrollTo=8CFQXIRpwsFV)
#
# >[Chargement des données](#scrollTo=uMGcEvsOzyHe)
#
# >[Initialisation du modèle de ML](#scrollTo=5rs8lLzQxNYJ)
#
# >[Training](#scrollTo=6finyiXVyRIq)
#
# >[Test du modèle](#scrollTo=X91E4eY62iJR)
#
# >[Sauvegarde des fichiers sur le drive](#scrollTo=aVHU4uZ77k_v)

# %% [markdown]
# # Imports classiques

# %%
# !pip install tqdm

from tqdm import tqdm

from keras import backend as K

K.set_image_dim_ordering('th')
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.23.4)

# %% [markdown]
# # Mise en place matérielle de l'environnement

# %% [markdown]
# ## Copie des fichiers du drive vers la machine distante

# %%
# !pip install -U -q PyDrive
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials


def uploadToDistantMachineFolder(driveFolderId,targetPath="~") :
  
  # Authentification et initialisation du client PyDrive
  auth.authenticate_user()
  gauth = GoogleAuth()
  gauth.credentials = GoogleCredentials.get_application_default()
  drive = GoogleDrive(gauth)

  # Choix d'un répertoire distant pour charger les donnéelocal_download_path = os.path.expanduser('~')
  try:
    os.makedirs(targetPath)
  except: pass

  # Ciblage du dossier drive contenant les données
  folderID = driveFolderId # les données se trouvent dans mon drive à l'URL https://drive.google.com/drive/u/0/folders/<>
  file_list = drive.ListFile({'q': "'{}' in parents".format(folderID)}).GetList()

  for f in file_list:
    print('title: %s, id: %s' % (f['title'], f['id']))
    fname = os.path.join(targetPath, f['title'])
    print('downloading to {}'.format(fname))
    f_ = drive.CreateFile({'id': f['id']})
    f_.GetContentFile(fname)

# %%
uploadToDistantMachineFolder("1ggpBuvJLQir2dJuNYuoYgcCjPADgg82O") # Bases complètes
uploadToDistantMachineFolder("1Ub9B3ibACYFWLQYaodKlls3ei6tgevzu") # Bases simples
# Out:
# title: bddBabyAIAll_valid.csv, id: 15dWrXSfyerB_x5w1MFBLGEUXhGGGT5y5
# downloading to ~/bddBabyAIAll_valid.csv
# title: bddBabyAIAll_train.csv, id: 18QAbwYoliyRccTndoTgNcmhcNLBLvcW3
# downloading to ~/bddBabyAIAll_train.csv
# title: bddBabyAIAll_test.csv, id: 1e5fpwAHr0SABTWxhsf4pYhstLVN-wzjq
# downloading to ~/bddBabyAIAll_test.csv
# title: bddBabyAIAll_valid_simples.csv, id: 1SxQtDxcS6t4j1tEQC47JAv5uFmQiBNuO
# downloading to ~/bddBabyAIAll_valid_simples.csv
# title: bddBabyAIAll_valid_complexes.csv, id: 1Y9aZVoI8-pdOgdJaEuWG9_Rp2iZhCd8m
# downloading to ~/bddBabyAIAll_valid_complexes.csv
# title: bddBabyAIAll_train_simples.csv, id: 1PknNL8eN_aQzppa7xEB4cvwtCrhXYIyA
# downloading to ~/bddBabyAIAll_train_simples.csv
# title: bddBabyAIAll_train_complexes.csv, id: 1v9MmXL4bRqv7NJUdnxq-74k5uJPd0qFC
# downloading to ~/bddBabyAIAll_train_complexes.csv
# title: bddBabyAIAll_test_simples.csv, id: 1B5GXrgh8OOUx4-ML2H1_uZR_7C52sWw4
# downloading to ~/bddBabyAIAll_test_simples.csv
# title: bddBabyAIAll_test_complexes.csv, id: 1KL7333XD9ZkS6AY3PSr5_4kSeYKInGB7
# downloading to ~/bddBabyAIAll_test_complexes.csv

# %% [markdown]
# Vérifier que les donnée sont bien chargées

# %%
from google.colab import files

files.os.listdir("~")
# Out:
# ['bddBabyAIAll_valid.csv',
#  'bddBabyAIAll_test.csv',
#  'bddBabyAIAll_test_simples.csv',
#  'bddBabyAIAll_valid_complexes.csv',
#  'bddBabyAIAll_test_complexes.csv',
#  'bddBabyAIAll_valid_simples.csv',
#  'bddBabyAIAll_train_complexes.csv',
#  'bddBabyAIAll_train_simples.csv',
#  'bddBabyAIAll_train.csv']

# %% [markdown]
# # Chargement des données

# %%
import pandas as pd
import numpy as np
import math

def load_data(path) :
    data = pd.read_csv(path)
    X = data.loc[:, ["pixel"+str(i) for i in range(1024)]].values.astype('float32')
    y = data.loc[:, ["shape"]].values.astype('int32')
    arr = np.arange(X.shape[0])
    np.random.shuffle(arr)    
    
    X_train = np.zeros((X.shape[0],X.shape[1]))
    Y_train = np.zeros((X.shape[0],3))
    y_train = np.zeros((X.shape[0],1))
    
    for i in range(X.shape[0]):
      X_train[i] = X[arr[i]]
      y_train[i] = y[arr[i]]
      try:
        Y_train[i,int(y_train[i])] = 1
      except:
        print(y[i])
    X_train = X_train.reshape(X_train.shape[0],1,32,32)

    return X_train,Y_train

# %%
X_train_all,Y_train_all = load_data("bddBabyAIAll_train.csv")
X_train_simple,Y_train_simple = load_data("bddBabyAIAll_train_simples.csv")
X_test_all, Y_test_all = load_data("bddBabyAIAll_test.csv")

# %% [markdown]
# # Initialisation du modèle de ML

# %%
from keras.layers import Input
from keras.models import Model, Sequential
from keras.layers.core import Reshape, Dense, Dropout, Flatten
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import Conv2D, UpSampling2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam, Adagrad
from keras import initializers

# %%
def classifier() :
  
  model = Sequential()
  
  model.add(Conv2D(64, (5, 5), input_shape=(1,32,32), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2,2)))
  
  model.add(Conv2D(32, (3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Dropout(0.5))
  model.add(Flatten())
  
  model.add(Dense(256))
  model.add(LeakyReLU(0.2))
  model.add(Dropout(0.3))
  
  model.add(Dense(32))
  model.add(LeakyReLU(0.2))
  model.add(Dropout(0.3))
  
  model.add(Dense(3, activation='softmax'))
  
  return model

# %% [markdown]
# # Training

# %% [markdown]
# ## Entrainement du classifieur

# %%
from keras.callbacks import ModelCheckpoint

def train(model, X, Y, epochs=1, batchSize=128, validation=None):
  
    batchCount = X.shape[0]//batchSize+1
    
    # Affichage des paramètres de train
    print('Epochs:',epochs)
    print('Batch size:',batchSize)
    print('Batches per epoch:',batchCount)
    
    # Programmation des sauvegardes des epochs
    filepath="weights_{epoch:02d}_{val_acc:.2f}.hdf5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]

    # on entraine le réseau en enregistrant les données de train de toutes les epoch
    history = model.fit(X,Y,batch_size=batchSize,epochs=epochs,validation_data=validation,callbacks=callbacks_list,verbose=2)
    
    return history

# %%
model = classifier()
model.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.0002, beta_1=0.5), metrics=['accuracy'])

epochs_simples = 25
epochs_all = 25
batchSize = 128

history_simple = train(model,X_train_simple,Y_train_simple,epochs_simples,batchSize,(X_test_all,Y_test_all))
history_complexe = train(model,X_train_all,Y_train_all,epochs_all,batchSize,(X_test_all,Y_test_all))
# Out:
# Epochs: 25
# Batch size: 128
# Batches per epoch: 313
# Train on 39996 samples, validate on 39992 samples
# Epoch 1/25
#  - 8s - loss: 0.4244 - acc: 0.8069 - val_loss: 0.3238 - val_acc: 0.8609
#
# Epoch 00001: val_acc improved from -inf to 0.86092, saving model to weights_01_0.86.hdf5
# Epoch 2/25
#  - 7s - loss: 0.2497 - acc: 0.9047 - val_loss: 0.2206 - val_acc: 0.9197
#
# Epoch 00002: val_acc improved from 0.86092 to 0.91968, saving model to weights_02_0.92.hdf5
# Epoch 3/25
#  - 7s - loss: 0.1789 - acc: 0.9325 - val_loss: 0.1814 - val_acc: 0.9322
#
# Epoch 00003: val_acc improved from 0.91968 to 0.93215, saving model to weights_03_0.93.hdf5
# Epoch 4/25
#  - 7s - loss: 0.1393 - acc: 0.9462 - val_loss: 0.1769 - val_acc: 0.9310
#
# Epoch 00004: val_acc did not improve from 0.93215
# Epoch 5/25
#  - 7s - loss: 0.1138 - acc: 0.9556 - val_loss: 0.1623 - val_acc: 0.9373
#
# Epoch 00005: val_acc improved from 0.93215 to 0.93730, saving model to weights_05_0.94.hdf5
# Epoch 6/25
#  - 7s - loss: 0.0941 - acc: 0.9632 - val_loss: 0.1919 - val_acc: 0.9318
#
# Epoch 00006: val_acc did not improve from 0.93730
# Epoch 7/25
#  - 7s - loss: 0.0800 - acc: 0.9694 - val_loss: 0.1726 - val_acc: 0.9406
#
# Epoch 00007: val_acc improved from 0.93730 to 0.94063, saving model to weights_07_0.94.hdf5
# Epoch 8/25
#  - 7s - loss: 0.0721 - acc: 0.9724 - val_loss: 0.1731 - val_acc: 0.9417
#
# Epoch 00008: val_acc improved from 0.94063 to 0.94172, saving model to weights_08_0.94.hdf5
# Epoch 9/25
#  - 7s - loss: 0.0614 - acc: 0.9765 - val_loss: 0.1679 - val_acc: 0.9459
#
# Epoch 00009: val_acc improved from 0.94172 to 0.94590, saving model to weights_09_0.95.hdf5
# Epoch 10/25
#  - 7s - loss: 0.0542 - acc: 0.9799 - val_loss: 0.2048 - val_acc: 0.9418
#
# Epoch 00010: val_acc did not improve from 0.94590
# Epoch 11/25
#  - 7s - loss: 0.0466 - acc: 0.9829 - val_loss: 0.2401 - val_acc: 0.9383
#
# Epoch 00011: val_acc did not improve from 0.94590
# Epoch 12/25
#  - 7s - loss: 0.0428 - acc: 0.9845 - val_loss: 0.1824 - val_acc: 0.9510
#
# Epoch 00012: val_acc improved from 0.94590 to 0.95102, saving model to weights_12_0.95.hdf5
# Epoch 13/25
#  - 7s - loss: 0.0385 - acc: 0.9860 - val_loss: 0.1904 - val_acc: 0.9512
#
# Epoch 00013: val_acc improved from 0.95102 to 0.95125, saving model to weights_13_0.95.hdf5
# Epoch 14/25
#  - 7s - loss: 0.0331 - acc: 0.9884 - val_loss: 0.2319 - val_acc: 0.9483
#
# Epoch 00014: val_acc did not improve from 0.95125
# Epoch 15/25
#  - 7s - loss: 0.0295 - acc: 0.9898 - val_loss: 0.1970 - val_acc: 0.9517
#
# Epoch 00015: val_acc improved from 0.95125 to 0.95171, saving model to weights_15_0.95.hdf5
# Epoch 16/25
#  - 7s - loss: 0.0301 - acc: 0.9894 - val_loss: 0.2175 - val_acc: 0.9469
#
# Epoch 00016: val_acc did not improve from 0.95171
# Epoch 17/25
#  - 7s - loss: 0.0236 - acc: 0.9916 - val_loss: 0.2736 - val_acc: 0.9467
#
# Epoch 00017: val_acc did not improve from 0.95171
# Epoch 18/25
#  - 7s - loss: 0.0225 - acc: 0.9929 - val_loss: 0.2119 - val_acc: 0.9532
#
# Epoch 00018: val_acc improved from 0.95171 to 0.95322, saving model to weights_18_0.95.hdf5
# Epoch 19/25
#  - 7s - loss: 0.0204 - acc: 0.9933 - val_loss: 0.2194 - val_acc: 0.9517
#
# Epoch 00019: val_acc did not improve from 0.95322
# Epoch 20/25
#  - 7s - loss: 0.0194 - acc: 0.9935 - val_loss: 0.3263 - val_acc: 0.9408
#
# Epoch 00020: val_acc did not improve from 0.95322
# Epoch 21/25
#  - 7s - loss: 0.0187 - acc: 0.9937 - val_loss: 0.2369 - val_acc: 0.9519
#
# Epoch 00021: val_acc did not improve from 0.95322
# Epoch 22/25
#  - 7s - loss: 0.0165 - acc: 0.9944 - val_loss: 0.2630 - val_acc: 0.9486
#
# Epoch 00022: val_acc did not improve from 0.95322
# Epoch 23/25
#  - 7s - loss: 0.0169 - acc: 0.9941 - val_loss: 0.2956 - val_acc: 0.9459
#
# Epoch 00023: val_acc did not improve from 0.95322
# Epoch 24/25
#  - 7s - loss: 0.0139 - acc: 0.9956 - val_loss: 0.2140 - val_acc: 0.9578
#
# Epoch 00024: val_acc improved from 0.95322 to 0.95784, saving model to weights_24_0.96.hdf5
# Epoch 25/25
#  - 7s - loss: 0.0136 - acc: 0.9954 - val_loss: 0.2350 - val_acc: 0.9534
#
# Epoch 00025: val_acc did not improve from 0.95784
# Epochs: 25
# Batch size: 128
# Batches per epoch: 625
# Train on 79992 samples, validate on 39992 samples
# Epoch 1/25
#  - 11s - loss: 0.0685 - acc: 0.9766 - val_loss: 0.0331 - val_acc: 0.9877
#
# Epoch 00001: val_acc improved from -inf to 0.98769, saving model to weights_01_0.99.hdf5
# Epoch 2/25
#  - 11s - loss: 0.0497 - acc: 0.9826 - val_loss: 0.0253 - val_acc: 0.9908
#
# Epoch 00002: val_acc improved from 0.98769 to 0.99085, saving model to weights_02_0.99.hdf5
# Epoch 3/25
#  - 11s - loss: 0.0419 - acc: 0.9853 - val_loss: 0.0215 - val_acc: 0.9931
#
# Epoch 00003: val_acc improved from 0.99085 to 0.99310, saving model to weights_03_0.99.hdf5
# Epoch 4/25
#  - 11s - loss: 0.0360 - acc: 0.9875 - val_loss: 0.0178 - val_acc: 0.9943
#
# Epoch 00004: val_acc improved from 0.99310 to 0.99432, saving model to weights_04_0.99.hdf5
# Epoch 5/25
#  - 11s - loss: 0.0322 - acc: 0.9888 - val_loss: 0.0150 - val_acc: 0.9948
#
# Epoch 00005: val_acc improved from 0.99432 to 0.99482, saving model to weights_05_0.99.hdf5
# Epoch 6/25
#  - 11s - loss: 0.0292 - acc: 0.9897 - val_loss: 0.0129 - val_acc: 0.9957
#
# Epoch 00006: val_acc improved from 0.99482 to 0.99570, saving model to weights_06_1.00.hdf5
# Epoch 7/25
#  - 11s - loss: 0.0260 - acc: 0.9913 - val_loss: 0.0108 - val_acc: 0.9966
#
# Epoch 00007: val_acc improved from 0.99570 to 0.99664, saving model to weights_07_1.00.hdf5
# Epoch 8/25
#  - 11s - loss: 0.0234 - acc: 0.9919 - val_loss: 0.0104 - val_acc: 0.9966
#
# Epoch 00008: val_acc did not improve from 0.99664
# Epoch 9/25
#  - 11s - loss: 0.0211 - acc: 0.9927 - val_loss: 0.0081 - val_acc: 0.9975
#
# Epoch 00009: val_acc improved from 0.99664 to 0.99755, saving model to weights_09_1.00.hdf5
# Epoch 10/25
#  - 11s - loss: 0.0202 - acc: 0.9931 - val_loss: 0.0078 - val_acc: 0.9977
#
# Epoch 00010: val_acc improved from 0.99755 to 0.99767, saving model to weights_10_1.00.hdf5
# Epoch 11/25
#  - 11s - loss: 0.0174 - acc: 0.9940 - val_loss: 0.0067 - val_acc: 0.9979
#
# Epoch 00011: val_acc improved from 0.99767 to 0.99787, saving model to weights_11_1.00.hdf5
# Epoch 12/25
#  - 11s - loss: 0.0170 - acc: 0.9943 - val_loss: 0.0060 - val_acc: 0.9980
#
# Epoch 00012: val_acc improved from 0.99787 to 0.99796, saving model to weights_12_1.00.hdf5
# Epoch 13/25
#  - 11s - loss: 0.0158 - acc: 0.9949 - val_loss: 0.0051 - val_acc: 0.9983
#
# Epoch 00013: val_acc improved from 0.99796 to 0.99833, saving model to weights_13_1.00.hdf5
# Epoch 14/25
#  - 11s - loss: 0.0139 - acc: 0.9956 - val_loss: 0.0050 - val_acc: 0.9986
#
# Epoch 00014: val_acc improved from 0.99833 to 0.99857, saving model to weights_14_1.00.hdf5
# Epoch 15/25
#  - 11s - loss: 0.0138 - acc: 0.9957 - val_loss: 0.0040 - val_acc: 0.9988
#
# Epoch 00015: val_acc improved from 0.99857 to 0.99878, saving model to weights_15_1.00.hdf5
# Epoch 16/25
#  - 11s - loss: 0.0129 - acc: 0.9958 - val_loss: 0.0040 - val_acc: 0.9986
#
# Epoch 00016: val_acc did not improve from 0.99878
# Epoch 17/25
#  - 11s - loss: 0.0133 - acc: 0.9958 - val_loss: 0.0038 - val_acc: 0.9988
#
# Epoch 00017: val_acc improved from 0.99878 to 0.99883, saving model to weights_17_1.00.hdf5
# Epoch 18/25
#  - 11s - loss: 0.0114 - acc: 0.9960 - val_loss: 0.0035 - val_acc: 0.9989
#
# Epoch 00018: val_acc improved from 0.99883 to 0.99892, saving model to weights_18_1.00.hdf5
# Epoch 19/25
#  - 11s - loss: 0.0113 - acc: 0.9963 - val_loss: 0.0031 - val_acc: 0.9991
#
# Epoch 00019: val_acc improved from 0.99892 to 0.99909, saving model to weights_19_1.00.hdf5
# Epoch 20/25
#  - 11s - loss: 0.0110 - acc: 0.9966 - val_loss: 0.0036 - val_acc: 0.9989
#
# Epoch 00020: val_acc did not improve from 0.99909
# Epoch 21/25
#  - 11s - loss: 0.0109 - acc: 0.9966 - val_loss: 0.0034 - val_acc: 0.9989
#
# Epoch 00021: val_acc did not improve from 0.99909
# Epoch 22/25
#  - 11s - loss: 0.0108 - acc: 0.9966 - val_loss: 0.0046 - val_acc: 0.9986
#
# Epoch 00022: val_acc did not improve from 0.99909
# Epoch 23/25
#  - 11s - loss: 0.0096 - acc: 0.9969 - val_loss: 0.0025 - val_acc: 0.9993
# Epoch 00023: val_acc improved from 0.99909 to 0.99926, saving model to weights_23_1.00.hdf5
# Epoch 24/25
#  - 11s - loss: 0.0091 - acc: 0.9971 - val_loss: 0.0025 - val_acc: 0.9993
#
# Epoch 00024: val_acc improved from 0.99926 to 0.99929, saving model to weights_24_1.00.hdf5
# Epoch 25/25
#  - 11s - loss: 0.0090 - acc: 0.9971 - val_loss: 0.0024 - val_acc: 0.9994
#
# Epoch 00025: val_acc improved from 0.99929 to 0.99937, saving model to weights_25_1.00.hdf5

# %% [markdown]
# ## Affichage des données de train

# %%
#print(history.history.keys())
import matplotlib.pyplot as plt
# Accuracy
plt.plot(history_simple.history['acc'][:]+history_complexe.history['acc'][:])
plt.plot(history_simple.history['val_acc'][:]+history_complexe.history['val_acc'][:])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.savefig('accuracy')

# Loss
plt.plot(history_simple.history['loss'][:]+history_complexe.history['loss'][:])
plt.plot(history_simple.history['val_loss'][:]+history_complexe.history['val_loss'][:])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.savefig('loss')

# %% [markdown]
# ## Enregistrement des données de train avec Pickle

# %%
import pickle
data = {'acc':history_simple.history['acc'][:]+history_complexe.history['acc'][:],
        'val_acc':history_simple.history['val_acc'][:]+history_complexe.history['val_acc'][:],
        'loss':history_simple.history['loss'][:]+history_complexe.history['loss'][:],
        'val_loss':history_simple.history['val_loss'][:]+history_complexe.history['val_loss'][:]}

with open (r"history.txt","wb") as f:
  pickle.dump(data, f)
  
  
from google.colab import files

files.download('history.txt')

# %% [markdown]
# # Test du modèle

# %%
from math import sqrt

def test(model, X, Y) :
  
  correct = 0
  
  for ID in range(X.shape[0]) :
    if np.argmax(model.predict(np.array([X[ID,:],]))) == np.argmax(Y[ID]) :
      correct += 1
      
  tau = correct/X.shape[0]
  barre = sqrt(tau*(1-tau)/X.shape[0])
  
  print("Tgen =",tau,"+-",barre)

# %%
test(model, X_test_all, Y_test_all)
# Out:
# Tgen = 0.999124824964993 +- 0.00014786683371104535

# %% [markdown]
# # Sauvegarde des fichiers en local

# %%
from google.colab import files

hdf = []

for file in files.os.listdir("/content/") :
  
    if ".hdf5" in file :
        hdf.append(file)
        #files.download("/content/"+file)
    #if ".png" in file :
    #    files.download("/content/"+file)
hdf.sort()
files.download("/content/"+hdf[-1])
