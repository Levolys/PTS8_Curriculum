# %% [markdown]
# # Sommaire

# %% [markdown]
# PYTHON 3

# %% [markdown]
# >[Sommaire](#scrollTo=WYyCyOO_r6lw)
#
# >[Imports classiques](#scrollTo=I4oNLLIcsJcg)
#
# >[Mise en place matérielle de l'environnement](#scrollTo=mkb9LHR1r_O0)
#
# >>[Copie des fichiers du drive vers la machine distante](#scrollTo=8CFQXIRpwsFV)
#
# >[Chargement des données](#scrollTo=uMGcEvsOzyHe)
#
# >[Initialisation du modèle de ML](#scrollTo=5rs8lLzQxNYJ)
#
# >[Training](#scrollTo=6finyiXVyRIq)
#
# >[Test du modèle](#scrollTo=X91E4eY62iJR)
#
# >[Sauvegarde des fichiers sur le drive](#scrollTo=aVHU4uZ77k_v)

# %% [markdown]
# # Imports classiques

# %%
# !pip install tqdm

from tqdm import tqdm

from keras import backend as K

K.set_image_dim_ordering('th')
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.23.4)

# %% [markdown]
# # Mise en place matérielle de l'environnement

# %% [markdown]
# ## Copie des fichiers du drive vers la machine distante

# %%
# !pip install -U -q PyDrive
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials


def uploadToDistantMachineFolder(driveFolderId,targetPath="~") :
  
  # Authentification et initialisation du client PyDrive
  auth.authenticate_user()
  gauth = GoogleAuth()
  gauth.credentials = GoogleCredentials.get_application_default()
  drive = GoogleDrive(gauth)

  # Choix d'un répertoire distant pour charger les donnéelocal_download_path = os.path.expanduser('~')
  try:
    os.makedirs(targetPath)
  except: pass

  # Ciblage du dossier drive contenant les données
  folderID = driveFolderId # les données se trouvent dans mon drive à l'URL https://drive.google.com/drive/u/0/folders/<>
  file_list = drive.ListFile({'q': "'{}' in parents".format(folderID)}).GetList()

  for f in file_list:
    print('title: %s, id: %s' % (f['title'], f['id']))
    fname = os.path.join(targetPath, f['title'])
    print('downloading to {}'.format(fname))
    f_ = drive.CreateFile({'id': f['id']})
    f_.GetContentFile(fname)

# %%
uploadToDistantMachineFolder("1ggpBuvJLQir2dJuNYuoYgcCjPADgg82O") # Bases complètes
uploadToDistantMachineFolder("1Ub9B3ibACYFWLQYaodKlls3ei6tgevzu") # Bases simples
# Out:
# title: bddBabyAIAll_valid.csv, id: 15dWrXSfyerB_x5w1MFBLGEUXhGGGT5y5
# downloading to ~/bddBabyAIAll_valid.csv
# title: bddBabyAIAll_train.csv, id: 18QAbwYoliyRccTndoTgNcmhcNLBLvcW3
# downloading to ~/bddBabyAIAll_train.csv
# title: bddBabyAIAll_test.csv, id: 1e5fpwAHr0SABTWxhsf4pYhstLVN-wzjq
# downloading to ~/bddBabyAIAll_test.csv
# title: bddBabyAIAll_valid_simples.csv, id: 1SxQtDxcS6t4j1tEQC47JAv5uFmQiBNuO
# downloading to ~/bddBabyAIAll_valid_simples.csv
# title: bddBabyAIAll_valid_complexes.csv, id: 1Y9aZVoI8-pdOgdJaEuWG9_Rp2iZhCd8m
# downloading to ~/bddBabyAIAll_valid_complexes.csv
# title: bddBabyAIAll_train_simples.csv, id: 1PknNL8eN_aQzppa7xEB4cvwtCrhXYIyA
# downloading to ~/bddBabyAIAll_train_simples.csv
# title: bddBabyAIAll_train_complexes.csv, id: 1v9MmXL4bRqv7NJUdnxq-74k5uJPd0qFC
# downloading to ~/bddBabyAIAll_train_complexes.csv
# title: bddBabyAIAll_test_simples.csv, id: 1B5GXrgh8OOUx4-ML2H1_uZR_7C52sWw4
# downloading to ~/bddBabyAIAll_test_simples.csv
# title: bddBabyAIAll_test_complexes.csv, id: 1KL7333XD9ZkS6AY3PSr5_4kSeYKInGB7
# downloading to ~/bddBabyAIAll_test_complexes.csv

# %% [markdown]
# Vérifier que les donnée sont bien chargées

# %%
from google.colab import files

files.os.listdir("~")
# Out:
# ['bddBabyAIAll_valid.csv',
#  'bddBabyAIAll_test.csv',
#  'bddBabyAIAll_test_simples.csv',
#  'bddBabyAIAll_valid_complexes.csv',
#  'bddBabyAIAll_test_complexes.csv',
#  'bddBabyAIAll_valid_simples.csv',
#  'bddBabyAIAll_train_complexes.csv',
#  'bddBabyAIAll_train_simples.csv',
#  'bddBabyAIAll_train.csv']

# %% [markdown]
# # Chargement des données

# %%
import pandas as pd
import numpy as np
import math

def load_data(path) :
    data = pd.read_csv(path)
    X = data.loc[:, ["pixel"+str(i) for i in range(1024)]].values.astype('float32')
    y = data.loc[:, ["shape"]].values.astype('int32')
    arr = np.arange(X.shape[0])
    np.random.shuffle(arr)    
    
    X_train = np.zeros((X.shape[0],X.shape[1]))
    Y_train = np.zeros((X.shape[0],3))
    y_train = np.zeros((X.shape[0],1))
    
    for i in range(X.shape[0]):
      X_train[i] = X[arr[i]]
      y_train[i] = y[arr[i]]
      try:
        Y_train[i,int(y_train[i])] = 1
      except:
        print(y[i])
    X_train = X_train.reshape(X_train.shape[0],1,32,32)

    return X_train,Y_train

# %%
X_train_all,Y_train_all = load_data("bddBabyAIAll_train.csv")
X_train_simple,Y_train_simple = load_data("bddBabyAIAll_train_simples.csv")
X_test_all, Y_test_all = load_data("bddBabyAIAll_test.csv")

# %% [markdown]
# # Initialisation du modèle de ML

# %%
from keras.layers import Input
from keras.models import Model, Sequential
from keras.layers.core import Reshape, Dense, Dropout, Flatten
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import Conv2D, UpSampling2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam, Adagrad
from keras import initializers

# %%
def classifier() :
  
  model = Sequential()
  
  model.add(Conv2D(32, (3, 3), input_shape=(1,32,32), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Dropout(0.5))
  model.add(Flatten())
  
  model.add(Dense(128))
  model.add(LeakyReLU(0.2))
  model.add(Dropout(0.3))
  
  model.add(Dense(32))
  model.add(LeakyReLU(0.2))
  model.add(Dropout(0.3))
  
  model.add(Dense(3, activation='softmax'))
  
  return model

# %% [markdown]
# # Training

# %% [markdown]
# ## Entrainement du classifieur

# %%
from keras.callbacks import ModelCheckpoint

def train(model, X, Y, epochs=1, batchSize=128, validation=None):
  
    batchCount = X.shape[0]//batchSize+1
    
    # Affichage des paramètres de train
    print('Epochs:',epochs)
    print('Batch size:',batchSize)
    print('Batches per epoch:',batchCount)
    
    # Programmation des sauvegardes des epochs
    filepath="weights_{epoch:02d}_{val_acc:.2f}.hdf5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]

    # on entraine le réseau en enregistrant les données de train de toutes les epoch
    history = model.fit(X,Y,batch_size=batchSize,epochs=epochs,validation_data=validation,callbacks=callbacks_list,verbose=2)
    
    return history

# %%
model = classifier()
model.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.0002, beta_1=0.5), metrics=['accuracy'])

epochs_simples = 25
epochs_all = 45
batchSize = 128

history_simple = train(model,X_train_simple,Y_train_simple,epochs_simples,batchSize,(X_test_all,Y_test_all))
history_complexe = train(model,X_train_all,Y_train_all,epochs_all,batchSize,(X_test_all,Y_test_all))
# Out:
# Epochs: 25
# Batch size: 128
# Batches per epoch: 313
# Train on 39996 samples, validate on 39992 samples
# Epoch 1/25
#  - 6s - loss: 0.4662 - acc: 0.7789 - val_loss: 0.4118 - val_acc: 0.8196
#
# Epoch 00001: val_acc improved from -inf to 0.81960, saving model to weights_01_0.82.hdf5
# Epoch 2/25
#  - 6s - loss: 0.3097 - acc: 0.8731 - val_loss: 0.3301 - val_acc: 0.8584
#
# Epoch 00002: val_acc improved from 0.81960 to 0.85841, saving model to weights_02_0.86.hdf5
# Epoch 3/25
#  - 5s - loss: 0.2472 - acc: 0.9013 - val_loss: 0.2697 - val_acc: 0.8895
#
# Epoch 00003: val_acc improved from 0.85841 to 0.88953, saving model to weights_03_0.89.hdf5
# Epoch 4/25
#  - 5s - loss: 0.2047 - acc: 0.9173 - val_loss: 0.2348 - val_acc: 0.9078
#
# Epoch 00004: val_acc improved from 0.88953 to 0.90776, saving model to weights_04_0.91.hdf5
# Epoch 5/25
#  - 5s - loss: 0.1773 - acc: 0.9288 - val_loss: 0.2322 - val_acc: 0.8984
#
# Epoch 00005: val_acc did not improve from 0.90776
# Epoch 6/25
#  - 5s - loss: 0.1574 - acc: 0.9367 - val_loss: 0.1995 - val_acc: 0.9187
#
# Epoch 00006: val_acc improved from 0.90776 to 0.91870, saving model to weights_06_0.92.hdf5
# Epoch 7/25
#  - 5s - loss: 0.1421 - acc: 0.9435 - val_loss: 0.1898 - val_acc: 0.9235
#
# Epoch 00007: val_acc improved from 0.91870 to 0.92348, saving model to weights_07_0.92.hdf5
# Epoch 8/25
#  - 5s - loss: 0.1288 - acc: 0.9493 - val_loss: 0.1874 - val_acc: 0.9244
#
# Epoch 00008: val_acc improved from 0.92348 to 0.92439, saving model to weights_08_0.92.hdf5
# Epoch 9/25
#  - 5s - loss: 0.1190 - acc: 0.9532 - val_loss: 0.1813 - val_acc: 0.9270
#
# Epoch 00009: val_acc improved from 0.92439 to 0.92702, saving model to weights_09_0.93.hdf5
# Epoch 10/25
#  - 5s - loss: 0.1103 - acc: 0.9564 - val_loss: 0.1774 - val_acc: 0.9290
#
# Epoch 00010: val_acc improved from 0.92702 to 0.92900, saving model to weights_10_0.93.hdf5
# Epoch 11/25
#  - 5s - loss: 0.1033 - acc: 0.9595 - val_loss: 0.1701 - val_acc: 0.9320
#
# Epoch 00011: val_acc improved from 0.92900 to 0.93199, saving model to weights_11_0.93.hdf5
# Epoch 12/25
#  - 5s - loss: 0.0963 - acc: 0.9619 - val_loss: 0.1679 - val_acc: 0.9345
#
# Epoch 00012: val_acc improved from 0.93199 to 0.93455, saving model to weights_12_0.93.hdf5
# Epoch 13/25
#  - 5s - loss: 0.0905 - acc: 0.9646 - val_loss: 0.1630 - val_acc: 0.9368
#
# Epoch 00013: val_acc improved from 0.93455 to 0.93682, saving model to weights_13_0.94.hdf5
# Epoch 14/25
#  - 5s - loss: 0.0853 - acc: 0.9671 - val_loss: 0.1658 - val_acc: 0.9374
#
# Epoch 00014: val_acc improved from 0.93682 to 0.93744, saving model to weights_14_0.94.hdf5
# Epoch 15/25
#  - 5s - loss: 0.0813 - acc: 0.9685 - val_loss: 0.1630 - val_acc: 0.9370
#
# Epoch 00015: val_acc did not improve from 0.93744
# Epoch 16/25
#  - 5s - loss: 0.0768 - acc: 0.9700 - val_loss: 0.1660 - val_acc: 0.9385
#
# Epoch 00016: val_acc improved from 0.93744 to 0.93847, saving model to weights_16_0.94.hdf5
# Epoch 17/25
#  - 5s - loss: 0.0736 - acc: 0.9717 - val_loss: 0.1731 - val_acc: 0.9376
#
# Epoch 00017: val_acc did not improve from 0.93847
# Epoch 18/25
#  - 5s - loss: 0.0691 - acc: 0.9729 - val_loss: 0.1654 - val_acc: 0.9393
#
# Epoch 00018: val_acc improved from 0.93847 to 0.93931, saving model to weights_18_0.94.hdf5
# Epoch 19/25
#  - 5s - loss: 0.0680 - acc: 0.9741 - val_loss: 0.1671 - val_acc: 0.9388
#
# Epoch 00019: val_acc did not improve from 0.93931
# Epoch 20/25
#  - 5s - loss: 0.0641 - acc: 0.9751 - val_loss: 0.1724 - val_acc: 0.9385
#
# Epoch 00020: val_acc did not improve from 0.93931
# Epoch 21/25
#  - 5s - loss: 0.0620 - acc: 0.9762 - val_loss: 0.1632 - val_acc: 0.9421
#
# Epoch 00021: val_acc improved from 0.93931 to 0.94211, saving model to weights_21_0.94.hdf5
# Epoch 22/25
#  - 5s - loss: 0.0585 - acc: 0.9776 - val_loss: 0.1763 - val_acc: 0.9393
#
# Epoch 00022: val_acc did not improve from 0.94211
# Epoch 23/25
#  - 5s - loss: 0.0558 - acc: 0.9785 - val_loss: 0.1677 - val_acc: 0.9411
#
# Epoch 00023: val_acc did not improve from 0.94211
# Epoch 24/25
#  - 5s - loss: 0.0554 - acc: 0.9792 - val_loss: 0.1619 - val_acc: 0.9435
#
# Epoch 00024: val_acc improved from 0.94211 to 0.94355, saving model to weights_24_0.94.hdf5
# Epoch 25/25
#  - 5s - loss: 0.0525 - acc: 0.9805 - val_loss: 0.1646 - val_acc: 0.9449
#
# Epoch 00025: val_acc improved from 0.94355 to 0.94490, saving model to weights_25_0.94.hdf5
# Epochs: 45
# Batch size: 128
# Batches per epoch: 625
# Train on 79992 samples, validate on 39992 samples
# Epoch 1/45
#  - 9s - loss: 0.1290 - acc: 0.9530 - val_loss: 0.0892 - val_acc: 0.9649
#
# Epoch 00001: val_acc improved from -inf to 0.96488, saving model to weights_01_0.96.hdf5
# Epoch 2/45
#  - 9s - loss: 0.1072 - acc: 0.9600 - val_loss: 0.0780 - val_acc: 0.9694
#
# Epoch 00002: val_acc improved from 0.96488 to 0.96944, saving model to weights_02_0.97.hdf5
# Epoch 3/45
#  - 9s - loss: 0.0979 - acc: 0.9628 - val_loss: 0.0721 - val_acc: 0.9725
#
# Epoch 00003: val_acc improved from 0.96944 to 0.97254, saving model to weights_03_0.97.hdf5
# Epoch 4/45
#  - 9s - loss: 0.0913 - acc: 0.9654 - val_loss: 0.0678 - val_acc: 0.9747
#
# Epoch 00004: val_acc improved from 0.97254 to 0.97472, saving model to weights_04_0.97.hdf5
# Epoch 5/45
#  - 9s - loss: 0.0866 - acc: 0.9665 - val_loss: 0.0625 - val_acc: 0.9763
#
# Epoch 00005: val_acc improved from 0.97472 to 0.97633, saving model to weights_05_0.98.hdf5
# Epoch 6/45
#  - 9s - loss: 0.0814 - acc: 0.9690 - val_loss: 0.0592 - val_acc: 0.9780
#
# Epoch 00006: val_acc improved from 0.97633 to 0.97796, saving model to weights_06_0.98.hdf5
# Epoch 7/45
#  - 9s - loss: 0.0780 - acc: 0.9705 - val_loss: 0.0591 - val_acc: 0.9769
#
# Epoch 00007: val_acc did not improve from 0.97796
# Epoch 8/45
#  - 9s - loss: 0.0745 - acc: 0.9720 - val_loss: 0.0538 - val_acc: 0.9798
#
# Epoch 00008: val_acc improved from 0.97796 to 0.97977, saving model to weights_08_0.98.hdf5
# Epoch 9/45
#  - 9s - loss: 0.0720 - acc: 0.9732 - val_loss: 0.0518 - val_acc: 0.9807
#
# Epoch 00009: val_acc improved from 0.97977 to 0.98068, saving model to weights_09_0.98.hdf5
# Epoch 10/45
#  - 9s - loss: 0.0697 - acc: 0.9739 - val_loss: 0.0499 - val_acc: 0.9814
#
# Epoch 00010: val_acc improved from 0.98068 to 0.98145, saving model to weights_10_0.98.hdf5
# Epoch 11/45
#  - 9s - loss: 0.0679 - acc: 0.9746 - val_loss: 0.0491 - val_acc: 0.9814
#
# Epoch 00011: val_acc did not improve from 0.98145
# Epoch 12/45
#  - 9s - loss: 0.0647 - acc: 0.9756 - val_loss: 0.0475 - val_acc: 0.9818
#
# Epoch 00012: val_acc improved from 0.98145 to 0.98185, saving model to weights_12_0.98.hdf5
# Epoch 13/45
#  - 9s - loss: 0.0630 - acc: 0.9761 - val_loss: 0.0438 - val_acc: 0.9841
#
# Epoch 00013: val_acc improved from 0.98185 to 0.98406, saving model to weights_13_0.98.hdf5
# Epoch 14/45
#  - 9s - loss: 0.0614 - acc: 0.9774 - val_loss: 0.0435 - val_acc: 0.9836
#
# Epoch 00014: val_acc did not improve from 0.98406
# Epoch 15/45
#  - 9s - loss: 0.0595 - acc: 0.9779 - val_loss: 0.0446 - val_acc: 0.9838
#
# Epoch 00015: val_acc did not improve from 0.98406
# Epoch 16/45
#  - 9s - loss: 0.0570 - acc: 0.9788 - val_loss: 0.0421 - val_acc: 0.9840
#
# Epoch 00016: val_acc did not improve from 0.98406
# Epoch 17/45
#  - 9s - loss: 0.0564 - acc: 0.9792 - val_loss: 0.0405 - val_acc: 0.9849
#
# Epoch 00017: val_acc improved from 0.98406 to 0.98491, saving model to weights_17_0.98.hdf5
# Epoch 18/45
#  - 9s - loss: 0.0544 - acc: 0.9799 - val_loss: 0.0404 - val_acc: 0.9846
#
# Epoch 00018: val_acc did not improve from 0.98491
# Epoch 19/45
#  - 9s - loss: 0.0529 - acc: 0.9803 - val_loss: 0.0397 - val_acc: 0.9848
#
# Epoch 00019: val_acc did not improve from 0.98491
# Epoch 20/45
#  - 9s - loss: 0.0525 - acc: 0.9803 - val_loss: 0.0374 - val_acc: 0.9862
#
# Epoch 00020: val_acc improved from 0.98491 to 0.98617, saving model to weights_20_0.99.hdf5
# Epoch 21/45
#  - 9s - loss: 0.0514 - acc: 0.9809 - val_loss: 0.0394 - val_acc: 0.9857
#
# Epoch 00021: val_acc did not improve from 0.98617
# Epoch 22/45
#  - 9s - loss: 0.0507 - acc: 0.9813 - val_loss: 0.0364 - val_acc: 0.9868
# Epoch 00022: val_acc improved from 0.98617 to 0.98681, saving model to weights_22_0.99.hdf5
# Epoch 23/45
#  - 9s - loss: 0.0493 - acc: 0.9817 - val_loss: 0.0395 - val_acc: 0.9856
#
# Epoch 00023: val_acc did not improve from 0.98681
# Epoch 24/45
#  - 9s - loss: 0.0485 - acc: 0.9825 - val_loss: 0.0348 - val_acc: 0.9871
#
# Epoch 00024: val_acc improved from 0.98681 to 0.98713, saving model to weights_24_0.99.hdf5
# Epoch 25/45
#  - 9s - loss: 0.0475 - acc: 0.9827 - val_loss: 0.0354 - val_acc: 0.9863
#
# Epoch 00025: val_acc did not improve from 0.98713
# Epoch 26/45
#  - 9s - loss: 0.0473 - acc: 0.9824 - val_loss: 0.0341 - val_acc: 0.9876
#
# Epoch 00026: val_acc improved from 0.98713 to 0.98756, saving model to weights_26_0.99.hdf5
# Epoch 27/45
#  - 9s - loss: 0.0475 - acc: 0.9826 - val_loss: 0.0337 - val_acc: 0.9876
#
# Epoch 00027: val_acc improved from 0.98756 to 0.98763, saving model to weights_27_0.99.hdf5
# Epoch 28/45
#  - 9s - loss: 0.0451 - acc: 0.9836 - val_loss: 0.0325 - val_acc: 0.9879
#
# Epoch 00028: val_acc improved from 0.98763 to 0.98795, saving model to weights_28_0.99.hdf5
# Epoch 29/45
#  - 9s - loss: 0.0451 - acc: 0.9832 - val_loss: 0.0326 - val_acc: 0.9883
#
# Epoch 00029: val_acc improved from 0.98795 to 0.98829, saving model to weights_29_0.99.hdf5
# Epoch 30/45
#  - 9s - loss: 0.0424 - acc: 0.9845 - val_loss: 0.0335 - val_acc: 0.9875
#
# Epoch 00030: val_acc did not improve from 0.98829
# Epoch 31/45
#  - 9s - loss: 0.0462 - acc: 0.9833 - val_loss: 0.0325 - val_acc: 0.9884
#
# Epoch 00031: val_acc improved from 0.98829 to 0.98843, saving model to weights_31_0.99.hdf5
# Epoch 32/45
#  - 9s - loss: 0.0429 - acc: 0.9840 - val_loss: 0.0320 - val_acc: 0.9881
#
# Epoch 00032: val_acc did not improve from 0.98843
# Epoch 33/45
#  - 9s - loss: 0.0425 - acc: 0.9850 - val_loss: 0.0319 - val_acc: 0.9881
#
# Epoch 00033: val_acc did not improve from 0.98843
# Epoch 34/45
#  - 9s - loss: 0.0413 - acc: 0.9849 - val_loss: 0.0300 - val_acc: 0.9891
#
# Epoch 00034: val_acc improved from 0.98843 to 0.98914, saving model to weights_34_0.99.hdf5
# Epoch 35/45
#  - 9s - loss: 0.0406 - acc: 0.9856 - val_loss: 0.0300 - val_acc: 0.9891
#
# Epoch 00035: val_acc did not improve from 0.98914
# Epoch 36/45
#  - 9s - loss: 0.0415 - acc: 0.9850 - val_loss: 0.0303 - val_acc: 0.9886
#
# Epoch 00036: val_acc did not improve from 0.98914
# Epoch 37/45
#  - 9s - loss: 0.0423 - acc: 0.9851 - val_loss: 0.0300 - val_acc: 0.9888
#
# Epoch 00037: val_acc did not improve from 0.98914
# Epoch 38/45
#  - 9s - loss: 0.0385 - acc: 0.9859 - val_loss: 0.0286 - val_acc: 0.9899
#
# Epoch 00038: val_acc improved from 0.98914 to 0.98988, saving model to weights_38_0.99.hdf5
# Epoch 39/45
#  - 9s - loss: 0.0391 - acc: 0.9858 - val_loss: 0.0294 - val_acc: 0.9889
#
# Epoch 00039: val_acc did not improve from 0.98988
# Epoch 40/45
#  - 9s - loss: 0.0395 - acc: 0.9856 - val_loss: 0.0289 - val_acc: 0.9893
#
# Epoch 00040: val_acc did not improve from 0.98988
# Epoch 41/45
#  - 9s - loss: 0.0373 - acc: 0.9868 - val_loss: 0.0270 - val_acc: 0.9902
#
# Epoch 00041: val_acc improved from 0.98988 to 0.99022, saving model to weights_41_0.99.hdf5
# Epoch 42/45
#  - 9s - loss: 0.0377 - acc: 0.9866 - val_loss: 0.0274 - val_acc: 0.9905
#
# Epoch 00042: val_acc improved from 0.99022 to 0.99054, saving model to weights_42_0.99.hdf5
# Epoch 43/45
#  - 9s - loss: 0.0376 - acc: 0.9866 - val_loss: 0.0284 - val_acc: 0.9898
#
# Epoch 00043: val_acc did not improve from 0.99054
# Epoch 44/45
#  - 9s - loss: 0.0373 - acc: 0.9868 - val_loss: 0.0266 - val_acc: 0.9908
#
# Epoch 00044: val_acc improved from 0.99054 to 0.99079, saving model to weights_44_0.99.hdf5
# Epoch 45/45
#  - 9s - loss: 0.0362 - acc: 0.9870 - val_loss: 0.0268 - val_acc: 0.9906
#
# Epoch 00045: val_acc did not improve from 0.99079

# %% [markdown]
# ## Affichage des données de train

# %%
#print(history.history.keys())
import matplotlib.pyplot as plt
# Accuracy
plt.plot(history_simple.history['acc'][:]+history_complexe.history['acc'][:])
plt.plot(history_simple.history['val_acc'][:]+history_complexe.history['val_acc'][:])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.savefig('accuracy')

# Loss
plt.plot(history_simple.history['loss'][:]+history_complexe.history['loss'][:])
plt.plot(history_simple.history['val_loss'][:]+history_complexe.history['val_loss'][:])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.savefig('loss')

# %% [markdown]
# ## Enregistrement des données de train avec Pickle

# %%
import pickle
data = {'acc':history_simple.history['acc'][:]+history_complexe.history['acc'][:],
        'val_acc':history_simple.history['val_acc'][:]+history_complexe.history['val_acc'][:],
        'loss':history_simple.history['loss'][:]+history_complexe.history['loss'][:],
        'val_loss':history_simple.history['val_loss'][:]+history_complexe.history['val_loss'][:]}

with open (r"history.txt","wb") as f:
  pickle.dump(data, f)
  
  
from google.colab import files

files.download('history.txt')

# %% [markdown]
# # Test du modèle

# %%
from math import sqrt

def test(model, X, Y) :
  
  correct = 0
  
  for ID in range(X.shape[0]) :
    if np.argmax(model.predict(np.array([X[ID,:],]))) == np.argmax(Y[ID]) :
      correct += 1
      
  tau = correct/X.shape[0]
  barre = sqrt(tau*(1-tau)/X.shape[0])
  
  print("Tgen =",tau,"+-",barre)

# %%
test(model, X_test_all, Y_test_all)
# Out:
# Tgen = 0.9858971794358872 +- 0.0005896336226573457

# %% [markdown]
# # Sauvegarde des fichiers en local

# %%
from google.colab import files

hdf = []

for file in files.os.listdir("/content/") :
  
    if ".hdf5" in file :
        hdf.append(file)
        #files.download("/content/"+file)
    #if ".png" in file :
    #    files.download("/content/"+file)
hdf.sort()
files.download("/content/"+hdf[-1])
