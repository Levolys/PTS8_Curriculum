# %% [markdown]
# PYTHON 3

# %% [markdown]
# # Sommaire

# %% [markdown]
# >[Sommaire](#scrollTo=WYyCyOO_r6lw)
#
# >[Imports classiques](#scrollTo=I4oNLLIcsJcg)
#
# >[Mise en place matérielle de l'environnement](#scrollTo=mkb9LHR1r_O0)
#
# >>[Copie des fichiers du drive vers la machine distante](#scrollTo=8CFQXIRpwsFV)
#
# >[Chargement des données](#scrollTo=uMGcEvsOzyHe)
#
# >[Initialisation du modèle de ML](#scrollTo=5rs8lLzQxNYJ)
#
# >[Training](#scrollTo=6finyiXVyRIq)
#
# >[Test du modèle](#scrollTo=X91E4eY62iJR)
#
# >[Sauvegarde des fichiers sur le drive](#scrollTo=aVHU4uZ77k_v)

# %% [markdown]
# # Imports classiques

# %%
# !pip install tqdm

from tqdm import tqdm

from keras import backend as K

K.set_image_dim_ordering('th')
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.23.4)

# %% [markdown]
# # Mise en place matérielle de l'environnement

# %% [markdown]
# ## Copie des fichiers du drive vers la machine distante

# %%
# !pip install -U -q PyDrive
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials


def uploadToDistantMachineFolder(driveFolderId,targetPath="~") :
  
  # Authentification et initialisation du client PyDrive
  auth.authenticate_user()
  gauth = GoogleAuth()
  gauth.credentials = GoogleCredentials.get_application_default()
  drive = GoogleDrive(gauth)

  # Choix d'un répertoire distant pour charger les donnéelocal_download_path = os.path.expanduser('~')
  try:
    os.makedirs(targetPath)
  except: pass

  # Ciblage du dossier drive contenant les données
  folderID = driveFolderId # les données se trouvent dans mon drive à l'URL https://drive.google.com/drive/u/0/folders/<>
  file_list = drive.ListFile({'q': "'{}' in parents".format(folderID)}).GetList()

  for f in file_list:
    print('title: %s, id: %s' % (f['title'], f['id']))
    fname = os.path.join(targetPath, f['title'])
    print('downloading to {}'.format(fname))
    f_ = drive.CreateFile({'id': f['id']})
    f_.GetContentFile(fname)

# %%
uploadToDistantMachineFolder("1ggpBuvJLQir2dJuNYuoYgcCjPADgg82O")
# Out:
# title: bddBabyAIAll_valid.csv, id: 15dWrXSfyerB_x5w1MFBLGEUXhGGGT5y5
# downloading to ~/bddBabyAIAll_valid.csv
# title: bddBabyAIAll_train.csv, id: 18QAbwYoliyRccTndoTgNcmhcNLBLvcW3
# downloading to ~/bddBabyAIAll_train.csv
# title: bddBabyAIAll_test.csv, id: 1e5fpwAHr0SABTWxhsf4pYhstLVN-wzjq
# downloading to ~/bddBabyAIAll_test.csv
# title: bddBabyAIAl_train .csv, id: 1bgfIThQkQywxhsMaxVkHndka9wWnuRNG
# downloading to ~/bddBabyAIAl_train .csv

# %% [markdown]
# Vérifier que les donnée sont bien chargées

# %%
from google.colab import files

files.os.listdir("~")
# Out:
# ['bddBabyAIAll_train.csv',
#  'bddBabyAIAll_valid.csv',
#  'bddBabyAIAll_test.csv',
#  'bddBabyAIAl_train .csv']

# %% [markdown]
# # Chargement des données

# %%
import pandas as pd
import numpy as np
import math

def load_data(path) :
    data = pd.read_csv(path)
    X = data.loc[:, ["pixel"+str(i) for i in range(1024)]].values.astype('float32')
    y = data.loc[:, ["shape"]].values.astype('int32')
    arr = np.arange(X.shape[0])
    np.random.shuffle(arr)    
    
    X_train = np.zeros((X.shape[0],X.shape[1]))
    Y_train = np.zeros((X.shape[0],3))
    y_train = np.zeros((X.shape[0],1))
    
    for i in range(X.shape[0]):
      X_train[i] = X[arr[i]]
      y_train[i] = y[arr[i]]
      try:
        Y_train[i,int(y_train[i])] = 1
      except:
        print(y[i])
    X_train = X_train.reshape(X_train.shape[0],1,32,32)

    return X_train,Y_train

# %%
X_train,Y_train = load_data("bddBabyAIAll_train.csv")
X_test, Y_test = load_data("bddBabyAIAll_test.csv")

# %% [markdown]
# # Initialisation du modèle de ML

# %%
from keras.layers import Input
from keras.models import Model, Sequential
from keras.layers.core import Reshape, Dense, Dropout, Flatten
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import Conv2D, UpSampling2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam, Adagrad
from keras import initializers

# %%
def classifier() :
  
  model = Sequential()
  
  model.add(Conv2D(32, (3, 3), input_shape=(1,32,32), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Dropout(0.5))
  model.add(Flatten())
  
  model.add(Dense(128))
  model.add(LeakyReLU(0.2))
  model.add(Dropout(0.3))
  
  model.add(Dense(32))
  model.add(LeakyReLU(0.2))
  model.add(Dropout(0.3))
  
  model.add(Dense(3, activation='softmax'))
  
  return model

# %% [markdown]
# # Training

# %% [markdown]
# ## Entrainement du classifieur

# %%
from keras.callbacks import ModelCheckpoint

def train(model, X, Y, epochs=1, batchSize=128, validation=None):
  
    batchCount = X.shape[0]//batchSize+1
    
    # Affichage des paramètres de train
    print('Epochs:',epochs)
    print('Batch size:',batchSize)
    print('Batches per epoch:',batchCount)
    
    # Programmation des sauvegardes des epochs
    filepath="weights_{epoch:02d}_{val_acc:.2f}.hdf5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]

    # on entraine le réseau en enregistrant les données de train de toutes les epoch
    history = model.fit(X,Y,batch_size=batchSize,epochs=epochs,validation_data=validation,callbacks=callbacks_list,verbose=2)
    
    return history

# %%
model = classifier()
model.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.0002, beta_1=0.5), metrics=['accuracy'])

epochs = 70
batchSize = 128

history = train(model,X_train,Y_train,epochs,batchSize,(X_test,Y_test))
# Out:
# Epochs: 70
# Batch size: 128
# Batches per epoch: 625
# Train on 79992 samples, validate on 39992 samples
# Epoch 1/70
#  - 11s - loss: 0.4090 - acc: 0.8156 - val_loss: 0.2710 - val_acc: 0.8949
#
# Epoch 00001: val_acc improved from -inf to 0.89487, saving model to weights_01_0.89.hdf5
# Epoch 2/70
#  - 10s - loss: 0.2536 - acc: 0.8995 - val_loss: 0.2005 - val_acc: 0.9207
#
# Epoch 00002: val_acc improved from 0.89487 to 0.92070, saving model to weights_02_0.92.hdf5
# Epoch 3/70
#  - 10s - loss: 0.2022 - acc: 0.9196 - val_loss: 0.1668 - val_acc: 0.9338
#
# Epoch 00003: val_acc improved from 0.92070 to 0.93378, saving model to weights_03_0.93.hdf5
# Epoch 4/70
#  - 10s - loss: 0.1747 - acc: 0.9308 - val_loss: 0.1442 - val_acc: 0.9419
#
# Epoch 00004: val_acc improved from 0.93378 to 0.94192, saving model to weights_04_0.94.hdf5
# Epoch 5/70
#  - 10s - loss: 0.1560 - acc: 0.9381 - val_loss: 0.1256 - val_acc: 0.9502
#
# Epoch 00005: val_acc improved from 0.94192 to 0.95017, saving model to weights_05_0.95.hdf5
# Epoch 6/70
#  - 10s - loss: 0.1422 - acc: 0.9436 - val_loss: 0.1147 - val_acc: 0.9528
#
# Epoch 00006: val_acc improved from 0.95017 to 0.95280, saving model to weights_06_0.95.hdf5
# Epoch 7/70
#  - 10s - loss: 0.1326 - acc: 0.9477 - val_loss: 0.1071 - val_acc: 0.9586
#
# Epoch 00007: val_acc improved from 0.95280 to 0.95863, saving model to weights_07_0.96.hdf5
# Epoch 8/70
#  - 10s - loss: 0.1237 - acc: 0.9508 - val_loss: 0.0963 - val_acc: 0.9613
#
# Epoch 00008: val_acc improved from 0.95863 to 0.96131, saving model to weights_08_0.96.hdf5
# Epoch 9/70
#  - 10s - loss: 0.1168 - acc: 0.9531 - val_loss: 0.0907 - val_acc: 0.9629
#
# Epoch 00009: val_acc improved from 0.96131 to 0.96290, saving model to weights_09_0.96.hdf5
# Epoch 10/70
#  - 10s - loss: 0.1091 - acc: 0.9568 - val_loss: 0.0870 - val_acc: 0.9648
#
# Epoch 00010: val_acc improved from 0.96290 to 0.96475, saving model to weights_10_0.96.hdf5
# Epoch 11/70
#  - 10s - loss: 0.1031 - acc: 0.9589 - val_loss: 0.0791 - val_acc: 0.9679
#
# Epoch 00011: val_acc improved from 0.96475 to 0.96791, saving model to weights_11_0.97.hdf5
# Epoch 12/70
#  - 10s - loss: 0.0979 - acc: 0.9615 - val_loss: 0.0754 - val_acc: 0.9706
#
# Epoch 00012: val_acc improved from 0.96791 to 0.97062, saving model to weights_12_0.97.hdf5
# Epoch 13/70
#  - 9s - loss: 0.0937 - acc: 0.9636 - val_loss: 0.0707 - val_acc: 0.9725
#
# Epoch 00013: val_acc improved from 0.97062 to 0.97247, saving model to weights_13_0.97.hdf5
# Epoch 14/70
#  - 10s - loss: 0.0873 - acc: 0.9660 - val_loss: 0.0655 - val_acc: 0.9748
#
# Epoch 00014: val_acc improved from 0.97247 to 0.97482, saving model to weights_14_0.97.hdf5
# Epoch 15/70
#  - 10s - loss: 0.0850 - acc: 0.9674 - val_loss: 0.0621 - val_acc: 0.9757
#
# Epoch 00015: val_acc improved from 0.97482 to 0.97567, saving model to weights_15_0.98.hdf5
# Epoch 16/70
#  - 10s - loss: 0.0827 - acc: 0.9677 - val_loss: 0.0592 - val_acc: 0.9788
#
# Epoch 00016: val_acc improved from 0.97567 to 0.97881, saving model to weights_16_0.98.hdf5
# Epoch 17/70
#  - 10s - loss: 0.0775 - acc: 0.9701 - val_loss: 0.0562 - val_acc: 0.9793
#
# Epoch 00017: val_acc improved from 0.97881 to 0.97926, saving model to weights_17_0.98.hdf5
# Epoch 18/70
#  - 10s - loss: 0.0752 - acc: 0.9714 - val_loss: 0.0545 - val_acc: 0.9799
#
# Epoch 00018: val_acc improved from 0.97926 to 0.97985, saving model to weights_18_0.98.hdf5
# Epoch 19/70
#  - 10s - loss: 0.0719 - acc: 0.9729 - val_loss: 0.0531 - val_acc: 0.9801
#
# Epoch 00019: val_acc improved from 0.97985 to 0.98007, saving model to weights_19_0.98.hdf5
# Epoch 20/70
#  - 9s - loss: 0.0706 - acc: 0.9732 - val_loss: 0.0495 - val_acc: 0.9812
#
# Epoch 00020: val_acc improved from 0.98007 to 0.98125, saving model to weights_20_0.98.hdf5
# Epoch 21/70
#  - 10s - loss: 0.0699 - acc: 0.9739 - val_loss: 0.0490 - val_acc: 0.9825
#
# Epoch 00021: val_acc improved from 0.98125 to 0.98252, saving model to weights_21_0.98.hdf5
# Epoch 22/70
#  - 10s - loss: 0.0665 - acc: 0.9749 - val_loss: 0.0521 - val_acc: 0.9828
#
# Epoch 00022: val_acc improved from 0.98252 to 0.98278, saving model to weights_22_0.98.hdf5
# Epoch 23/70
#  - 10s - loss: 0.0642 - acc: 0.9763 - val_loss: 0.0464 - val_acc: 0.9821
# Epoch 00023: val_acc did not improve from 0.98278
# Epoch 24/70
#  - 10s - loss: 0.0632 - acc: 0.9762 - val_loss: 0.0458 - val_acc: 0.9822
#
# Epoch 00024: val_acc did not improve from 0.98278
# Epoch 25/70
#  - 10s - loss: 0.0618 - acc: 0.9766 - val_loss: 0.0450 - val_acc: 0.9832
#
# Epoch 00025: val_acc improved from 0.98278 to 0.98321, saving model to weights_25_0.98.hdf5
# Epoch 26/70
#  - 10s - loss: 0.0607 - acc: 0.9774 - val_loss: 0.0431 - val_acc: 0.9846
#
# Epoch 00026: val_acc improved from 0.98321 to 0.98463, saving model to weights_26_0.98.hdf5
# Epoch 27/70
#  - 10s - loss: 0.0591 - acc: 0.9774 - val_loss: 0.0418 - val_acc: 0.9842
#
# Epoch 00027: val_acc did not improve from 0.98463
# Epoch 28/70
#  - 10s - loss: 0.0566 - acc: 0.9787 - val_loss: 0.0421 - val_acc: 0.9844
#
# Epoch 00028: val_acc did not improve from 0.98463
# Epoch 29/70
#  - 10s - loss: 0.0553 - acc: 0.9795 - val_loss: 0.0392 - val_acc: 0.9858
#
# Epoch 00029: val_acc improved from 0.98463 to 0.98581, saving model to weights_29_0.99.hdf5
# Epoch 30/70
#  - 10s - loss: 0.0556 - acc: 0.9797 - val_loss: 0.0381 - val_acc: 0.9861
#
# Epoch 00030: val_acc improved from 0.98581 to 0.98612, saving model to weights_30_0.99.hdf5
# Epoch 31/70
#  - 9s - loss: 0.0529 - acc: 0.9798 - val_loss: 0.0414 - val_acc: 0.9845
#
# Epoch 00031: val_acc did not improve from 0.98612
# Epoch 32/70
#  - 10s - loss: 0.0544 - acc: 0.9803 - val_loss: 0.0372 - val_acc: 0.9857
#
# Epoch 00032: val_acc did not improve from 0.98612
# Epoch 33/70
#  - 9s - loss: 0.0514 - acc: 0.9810 - val_loss: 0.0361 - val_acc: 0.9869
#
# Epoch 00033: val_acc improved from 0.98612 to 0.98694, saving model to weights_33_0.99.hdf5
# Epoch 34/70
#  - 9s - loss: 0.0523 - acc: 0.9808 - val_loss: 0.0357 - val_acc: 0.9871
#
# Epoch 00034: val_acc improved from 0.98694 to 0.98714, saving model to weights_34_0.99.hdf5
# Epoch 35/70
#  - 10s - loss: 0.0502 - acc: 0.9816 - val_loss: 0.0355 - val_acc: 0.9868
#
# Epoch 00035: val_acc did not improve from 0.98714
# Epoch 36/70
#  - 9s - loss: 0.0490 - acc: 0.9819 - val_loss: 0.0344 - val_acc: 0.9874
#
# Epoch 00036: val_acc improved from 0.98714 to 0.98738, saving model to weights_36_0.99.hdf5
# Epoch 37/70
#  - 10s - loss: 0.0484 - acc: 0.9824 - val_loss: 0.0333 - val_acc: 0.9879
#
# Epoch 00037: val_acc improved from 0.98738 to 0.98795, saving model to weights_37_0.99.hdf5
# Epoch 38/70
#  - 10s - loss: 0.0477 - acc: 0.9824 - val_loss: 0.0352 - val_acc: 0.9868
#
# Epoch 00038: val_acc did not improve from 0.98795
# Epoch 39/70
#  - 10s - loss: 0.0482 - acc: 0.9822 - val_loss: 0.0374 - val_acc: 0.9864
#
# Epoch 00039: val_acc did not improve from 0.98795
# Epoch 40/70
#  - 9s - loss: 0.0479 - acc: 0.9828 - val_loss: 0.0326 - val_acc: 0.9882
#
# Epoch 00040: val_acc improved from 0.98795 to 0.98816, saving model to weights_40_0.99.hdf5
# Epoch 41/70
#  - 10s - loss: 0.0445 - acc: 0.9836 - val_loss: 0.0322 - val_acc: 0.9886
#
# Epoch 00041: val_acc improved from 0.98816 to 0.98856, saving model to weights_41_0.99.hdf5
# Epoch 42/70
#  - 10s - loss: 0.0467 - acc: 0.9829 - val_loss: 0.0322 - val_acc: 0.9885
#
# Epoch 00042: val_acc did not improve from 0.98856
# Epoch 43/70
#  - 10s - loss: 0.0449 - acc: 0.9840 - val_loss: 0.0346 - val_acc: 0.9872
#
# Epoch 00043: val_acc did not improve from 0.98856
# Epoch 44/70
#  - 10s - loss: 0.0428 - acc: 0.9840 - val_loss: 0.0333 - val_acc: 0.9873
#
# Epoch 00044: val_acc did not improve from 0.98856
# Epoch 45/70
#  - 9s - loss: 0.0427 - acc: 0.9845 - val_loss: 0.0326 - val_acc: 0.9882
#
# Epoch 00045: val_acc did not improve from 0.98856
# Epoch 46/70
#  - 9s - loss: 0.0421 - acc: 0.9849 - val_loss: 0.0306 - val_acc: 0.9887
#
# Epoch 00046: val_acc improved from 0.98856 to 0.98873, saving model to weights_46_0.99.hdf5
# Epoch 47/70
#  - 10s - loss: 0.0429 - acc: 0.9849 - val_loss: 0.0310 - val_acc: 0.9891
#
# Epoch 00047: val_acc improved from 0.98873 to 0.98907, saving model to weights_47_0.99.hdf5
# Epoch 48/70
#  - 9s - loss: 0.0406 - acc: 0.9851 - val_loss: 0.0298 - val_acc: 0.9895
# Epoch 00048: val_acc improved from 0.98907 to 0.98948, saving model to weights_48_0.99.hdf5
# Epoch 49/70
#  - 10s - loss: 0.0407 - acc: 0.9851 - val_loss: 0.0303 - val_acc: 0.9887
#
# Epoch 00049: val_acc did not improve from 0.98948
# Epoch 50/70
#  - 10s - loss: 0.0404 - acc: 0.9853 - val_loss: 0.0279 - val_acc: 0.9899
#
# Epoch 00050: val_acc improved from 0.98948 to 0.98986, saving model to weights_50_0.99.hdf5
# Epoch 51/70
#  - 10s - loss: 0.0393 - acc: 0.9858 - val_loss: 0.0288 - val_acc: 0.9894
#
# Epoch 00051: val_acc did not improve from 0.98986
# Epoch 52/70
#  - 10s - loss: 0.0396 - acc: 0.9859 - val_loss: 0.0280 - val_acc: 0.9898
#
# Epoch 00052: val_acc did not improve from 0.98986
# Epoch 53/70
#  - 9s - loss: 0.0402 - acc: 0.9857 - val_loss: 0.0287 - val_acc: 0.9893
#
# Epoch 00053: val_acc did not improve from 0.98986
# Epoch 54/70
#  - 9s - loss: 0.0397 - acc: 0.9858 - val_loss: 0.0292 - val_acc: 0.9895
#
# Epoch 00054: val_acc did not improve from 0.98986
# Epoch 55/70
#  - 10s - loss: 0.0379 - acc: 0.9863 - val_loss: 0.0298 - val_acc: 0.9889
#
# Epoch 00055: val_acc did not improve from 0.98986
# Epoch 56/70
#  - 9s - loss: 0.0384 - acc: 0.9867 - val_loss: 0.0277 - val_acc: 0.9900
#
# Epoch 00056: val_acc improved from 0.98986 to 0.99003, saving model to weights_56_0.99.hdf5
# Epoch 57/70
#  - 10s - loss: 0.0384 - acc: 0.9862 - val_loss: 0.0280 - val_acc: 0.9899
#
# Epoch 00057: val_acc did not improve from 0.99003
# Epoch 58/70
#  - 10s - loss: 0.0385 - acc: 0.9866 - val_loss: 0.0275 - val_acc: 0.9899
#
# Epoch 00058: val_acc did not improve from 0.99003
# Epoch 59/70
#  - 10s - loss: 0.0379 - acc: 0.9868 - val_loss: 0.0299 - val_acc: 0.9892
#
# Epoch 00059: val_acc did not improve from 0.99003
# Epoch 60/70
#  - 9s - loss: 0.0377 - acc: 0.9868 - val_loss: 0.0285 - val_acc: 0.9892
#
# Epoch 00060: val_acc did not improve from 0.99003
# Epoch 61/70
#  - 9s - loss: 0.0365 - acc: 0.9870 - val_loss: 0.0279 - val_acc: 0.9903
#
# Epoch 00061: val_acc improved from 0.99003 to 0.99026, saving model to weights_61_0.99.hdf5
# Epoch 62/70
#  - 9s - loss: 0.0361 - acc: 0.9874 - val_loss: 0.0266 - val_acc: 0.9904
#
# Epoch 00062: val_acc improved from 0.99026 to 0.99039, saving model to weights_62_0.99.hdf5
# Epoch 63/70
#  - 9s - loss: 0.0365 - acc: 0.9872 - val_loss: 0.0266 - val_acc: 0.9903
#
# Epoch 00063: val_acc did not improve from 0.99039
# Epoch 64/70
#  - 10s - loss: 0.0357 - acc: 0.9872 - val_loss: 0.0292 - val_acc: 0.9892
#
# Epoch 00064: val_acc did not improve from 0.99039
# Epoch 65/70
#  - 9s - loss: 0.0348 - acc: 0.9872 - val_loss: 0.0274 - val_acc: 0.9901
#
# Epoch 00065: val_acc did not improve from 0.99039
# Epoch 66/70
#  - 10s - loss: 0.0342 - acc: 0.9881 - val_loss: 0.0256 - val_acc: 0.9915
#
# Epoch 00066: val_acc improved from 0.99039 to 0.99149, saving model to weights_66_0.99.hdf5
# Epoch 67/70
#  - 9s - loss: 0.0347 - acc: 0.9874 - val_loss: 0.0263 - val_acc: 0.9911
#
# Epoch 00067: val_acc did not improve from 0.99149
# Epoch 68/70
#  - 9s - loss: 0.0354 - acc: 0.9878 - val_loss: 0.0258 - val_acc: 0.9910
#
# Epoch 00068: val_acc did not improve from 0.99149
# Epoch 69/70
#  - 9s - loss: 0.0342 - acc: 0.9878 - val_loss: 0.0284 - val_acc: 0.9898
#
# Epoch 00069: val_acc did not improve from 0.99149
# Epoch 70/70
#  - 9s - loss: 0.0344 - acc: 0.9880 - val_loss: 0.0275 - val_acc: 0.9898
#
# Epoch 00070: val_acc did not improve from 0.99149

# %% [markdown]
# ## Affichage des données de train

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.savefig('accuracy')

# Loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.savefig('loss')

# %% [markdown]
# ## Enregistrement des données de train avec Pickle

# %%
import pickle

data = {'acc':history.history['acc'][:],
        'val_acc':history.history['val_acc'][:],
        'loss':history.history['loss'][:],
        'val_loss':history.history['val_loss'][:]}

with open (r"history.txt","wb") as f:
  pickle.dump(data, f)
  
  
from google.colab import files

files.download('history.txt')

# %% [markdown]
# # Test du modèle

# %%
from math import sqrt

def test(model, X, Y) :
  
  correct = 0
  
  for ID in range(X.shape[0]) :
    if np.argmax(model.predict(np.array([X[ID,:],]))) == np.argmax(Y[ID]) :
      correct += 1
      
  tau = correct/X.shape[0]
  barre = sqrt(tau*(1-tau)/X.shape[0])
  
  print("Tgen =",tau,"+-",barre)

# %%
test(model, X_test, Y_test)
# Out:
# Tgen = 0.9847219443888777 +- 0.0006133442377062238

# %% [markdown]
# # Sauvegarde des fichiers en local

# %%
from google.colab import files

hdf = []

for file in files.os.listdir("/content/") :
  
    if ".hdf5" in file :
        hdf.append(file)
        #files.download("/content/"+file)
    #if ".png" in file :
    #    files.download("/content/"+file)
hdf.sort()
files.download("/content/"+hdf[-1])
